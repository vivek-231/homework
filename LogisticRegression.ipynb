# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-231/homework/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from pickle import dump
from pickle import load

# %%
df=pd.read_csv("/claimants.csv")

# %%
df
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     NaN   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %%
df.isnull()
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 0       False     False   False     False     False   False  False
# 1       False     False   False     False     False   False  False
# 2       False     False   False     False     False   False  False
# 3       False     False   False     False     False   False  False
# 4       False     False   False     False     False   False  False
# ...       ...       ...     ...       ...       ...     ...    ...
# 1335    False     False   False     False     False    True  False
# 1336    False     False   False     False     False   False  False
# 1337    False     False   False     False     False   False  False
# 1338    False     False   False     False     False   False  False
# 1339    False     False   False     False     False   False  False
#
# [1340 rows x 7 columns]

# %%
df.fillna(1,inplace=False)
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     1.0   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %%
df.corr()
# Out:
#            CASENUM  ATTORNEY    CLMSEX  CLMINSUR  SEATBELT    CLMAGE      LOSS
# CASENUM   1.000000  0.011717  0.028151  0.046044 -0.010003 -0.002512 -0.049590
# ATTORNEY  0.011717  1.000000  0.079674  0.079439 -0.057189  0.010680 -0.219715
# CLMSEX    0.028151  0.079674  1.000000  0.066413 -0.015024 -0.023195 -0.027611
# CLMINSUR  0.046044  0.079439  0.066413  1.000000  0.021154  0.049493  0.005821
# SEATBELT -0.010003 -0.057189 -0.015024  0.021154  1.000000 -0.027992  0.111189
# CLMAGE   -0.002512  0.010680 -0.023195  0.049493 -0.027992  1.000000  0.064612
# LOSS     -0.049590 -0.219715 -0.027611  0.005821  0.111189  0.064612  1.000000

# %%
correlation=df['ATTORNEY'].corr(df['LOSS'])
correlation
# Out:
# -0.2197150271023389

# %%
correlation=df['ATTORNEY'].corr(df['CLMSEX'])
correlation
# Out:
# 0.07967388309782608

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x='ATTORNEY',y='LOSS',data=df)
plt.title('CORRELATION BETWEEN ATTORNEY AND LOSS')
plt.xlabel('ATTORNEY')
plt.ylabel('LOSS')
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from pickle import dump
from pickle import load
claiments=pd.read_csv("/claimants.csv")
claiments.drop(['CASENUM'],inplace=True,axis=1)
claiments.dropna(inplace=True)
claiments
x=claiments.iloc[:,[1,2,3,4,5]]
print(x)
y=claiments.iloc[:,0]
print(y)
model=LogisticRegression()
model.fit(x,y)
dump(model,open('claimants.csv','wb'))
# Out:
#       CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        0.0       1.0       0.0    50.0  34.940
# 1        1.0       0.0       0.0    18.0   0.891
# 2        0.0       1.0       0.0     5.0   0.330
# 3        0.0       1.0       1.0    31.0   0.037
# 4        0.0       1.0       0.0    30.0   0.038
# ...      ...       ...       ...     ...     ...
# 1334     1.0       1.0       0.0    16.0   0.060
# 1336     1.0       1.0       0.0    46.0   3.705
# 1337     1.0       1.0       0.0    39.0   0.099
# 1338     1.0       0.0       0.0     8.0   3.177
# 1339     1.0       1.0       0.0    30.0   0.688
#
# [1096 rows x 5 columns]
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1334    1
# 1336    0
# 1337    1
# 1338    0
# 1339    1
# Name: ATTORNEY, Length: 1096, dtype: int64
