# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-231/homework/blob/main/RecomendedOperator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cosine ex: reels suggestion
#corr ex: Ice cream and temperature

# User-Based Collaborative Filtering
# Finds users with similar preferences and recommends items liked by those users.
# Example: If RAJU  have similar movie preferences, RAJU’s favorite movie might be recommended to Ramu.

# (ii) Item-Based Collaborative Filtering
# Finds similar items based on users’ interaction history.
# Example: If many users who watched "" also watched "Blade Runner", then "Blade Runner" is recommended to users who watched "The Matrix."

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path="/content/drive/MyDrive/Movie.csv"

# %%
df=pd.read_csv(file_path)

# %%
df
# Out:
#       userId             movie  rating
# 0          3  Toy Story (1995)     4.0
# 1          6  Toy Story (1995)     5.0
# 2          8  Toy Story (1995)     4.0
# 3         10  Toy Story (1995)     4.0
# 4         11  Toy Story (1995)     4.5
# ...      ...               ...     ...
# 8987    7087  GoldenEye (1995)     3.0
# 8988    7088  GoldenEye (1995)     1.0
# 8989    7105  GoldenEye (1995)     2.0
# 8990    7113  GoldenEye (1995)     3.0
# 8991    7117  GoldenEye (1995)     3.0
#
# [8992 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8992 entries, 0 to 8991
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userId  8992 non-null   int64
#  1   movie   8992 non-null   object
#  2   rating  8992 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 210.9+ KB

# %%
array=df.values

# %%
array
# Out:
# array([[3, 'Toy Story (1995)', 4.0],
#        [6, 'Toy Story (1995)', 5.0],
#        [8, 'Toy Story (1995)', 4.0],
#        ...,
#        [7105, 'GoldenEye (1995)', 2.0],
#        [7113, 'GoldenEye (1995)', 3.0],
#        [7117, 'GoldenEye (1995)', 3.0]], dtype=object)
