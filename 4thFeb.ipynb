# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-231/homework/blob/main/4thFeb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
import pandas as pd
from google.colab import files
uploaded  = files.upload()
file_name = list(uploaded.keys())[0]
cars = pd.read_csv(file_name)
# Out:
#      <input type="file" id="files-bcf34be2-f614-41df-ae10-7453773e6c26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcf34be2-f614-41df-ae10-7453773e6c26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ml_w=smf.ols('MPG~WT',data=cars).fit()
print(ml_w.tvalues,'\n',ml_w.pvalues)
# Out:
# Intercept    14.248923
# WT           -5.508067
# dtype: float64
#  Intercept    1.550788e-23
# WT           4.383467e-07
# dtype: float64

# %%
ml_w=smf.ols('MPG~WT+VOL',data=cars).fit()
print(ml_w.tvalues,'\n',ml_w.pvalues)
# Out:
# Intercept    12.545736
# WT            0.489876
# VOL          -0.709604
# dtype: float64
#  Intercept    2.141975e-20
# WT           6.255966e-01
# VOL          4.800657e-01
# dtype: float64

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
(ml_w.rsquared,ml_w.rsquared_adj)
# Out:
# (0.2821095616445982, 0.2637021145072803)

# %%
ml_w=smf.ols('MPG~WT',data=cars).fit()
print(ml_w.tvalues,'\n',ml_w.pvalues)
ml_wv=smf.ols('MPG~WT+VOL',data=cars).fit()
print(ml_wv.tvalues,'\n',ml_wv.pvalues)

import statsmodels.api as sm
qqplot=sm.qqplot(model.residuals,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()
# Out:
# Intercept    14.248923
# WT           -5.508067
# dtype: float64
#  Intercept    1.550788e-23
# WT           4.383467e-07
# dtype: float64
# Intercept    12.545736
# WT            0.489876
# VOL          -0.709604
# dtype: float64
#  Intercept    2.141975e-20
# WT           6.255966e-01
# VOL          4.800657e-01
# dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7c5b26bd4a6c> in <cell line: 0>()
#       5
#       6 import statsmodels.api as sm
# ----> 7 qqplot=sm.qqplot(model.residuals,line='q')
#       8 plt.title("Normal Q-Q plot of residuals")
#       9 plt.show()
#
# NameError: name 'model' is not defined
